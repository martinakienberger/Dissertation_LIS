# %% [markdown]
# ## Erschließungsstrategien für unbekannten Wortschatz von DaF-Lernenden an spanischen Universitäten (2017-19)
# ### Faktorenanalyse und IRT-Analyse der Fragegruppen im Likert-Format

# %%
MyData <- read.csv2(file="D:\\Daten\\DISS\\Daten\\Estrategias_Estudiantes_Analyse.csv", 
                    header=TRUE, sep=",", fileEncoding = "UTF-16")

# %%
MyData[MyData == 0] <- NA

# %% [markdown]
# #### Likert-Variablen auswählen
#
# Spalten, die Likert-Items enthalten, werden ausgewählt und in Vektoren zusammengefasst.

# %%
get_vec <- function(df,name){
    vec <- c()
    for (i in 1:ncol(df)){
        if (grepl(name, colnames(df)[i]) & !grepl("TEXT",colnames(df)[i]) ){
            vec <- c(vec, i)
        }
    }
    vec
}

# %%
vec_AQ2 <- get_vec(MyData,"A.Q2")
vec_AQ3 <- get_vec(MyData,"A.Q3")
vec_CQ1 <- get_vec(MyData,"C.Q1")

# %%
vec_ACQ <- c(vec_AQ2,vec_AQ3,vec_CQ1)

# %% [markdown]
# #### Funktion für Datenformat (Integer)

# %%
convert_data <- function(df,cols){
    X <- df[,cols]
    X <- do.call(cbind.data.frame,lapply(X,function(x) as.integer(as.character(x))))
    colnames(X) <- colnames(df)[cols]
    X
}

# %% [markdown]
# ### Deskriptive Analyse

# %%
library("psych")

# %%
describe(MyData[vec_AQ2])
# Out:
#        vars n   mean     sd        median trimmed  mad    min max range
# A.Q2_1 1    390 2.520513 1.0890149 2      2.461538 1.4826 1   5   4
# A.Q2_2 2    390 3.551282 0.8551588 4      3.560897 1.4826 1   5   4
# A.Q2_3 3    390 3.871795 0.9614547 4      3.974359 1.4826 1   5   4
# A.Q2_4 4    390 4.066667 0.9861074 4      4.185897 1.4826 1   5   4
# A.Q2_5 5    390 3.430769 0.9956600 3      3.461538 1.4826 1   5   4
# A.Q2_6 6    390 3.230769 1.1839010 3      3.285256 1.4826 1   5   4
# A.Q2_7 7    390 4.305128 0.8733262 5      4.455128 0.0000 1   5   4
#        skew       kurtosis     se
# A.Q2_1  0.3645210 -0.451102764 0.05514441
# A.Q2_2 -0.2821606  0.221941437 0.04330265
# A.Q2_3 -0.6776174  0.006634709 0.04868515
# A.Q2_4 -0.7748443 -0.225471612 0.04993349
# A.Q2_5 -0.3468764 -0.230960706 0.05041720
# A.Q2_6 -0.2661795 -0.778973417 0.05994916
# A.Q2_7 -1.3460387  1.666411950 0.04422259

# %%
describe(MyData[vec_AQ3])
# Out:
#         vars n   mean     sd        median trimmed  mad    min max range
# A.Q3_1   1   390 3.048718 1.2126946 3      3.060897 1.4826 1   5   4
# A.Q3_2   2   389 3.969152 0.9465480 4      4.076677 1.4826 1   5   4
# A.Q3_3   3   388 2.976804 1.3282765 3      2.971154 1.4826 1   5   4
# A.Q3_4   4   390 2.917949 1.1883911 3      2.903846 1.4826 1   5   4
# A.Q3_5   5   390 2.561538 1.2357393 2      2.500000 1.4826 1   5   4
# A.Q3_6   6   390 3.743590 1.0854956 4      3.852564 1.4826 1   5   4
# A.Q3_7   7   390 3.571795 1.1511587 4      3.653846 1.4826 1   5   4
# A.Q3_8   8   390 3.638462 1.1650690 4      3.740385 1.4826 1   5   4
# A.Q3_9   9   390 3.958974 1.0481267 4      4.102564 1.4826 1   5   4
# A.Q3_28 10   390 3.789744 1.0474096 4      3.897436 1.4826 1   5   4
# A.Q3_10 11   390 3.171795 1.1622708 3      3.185897 1.4826 1   5   4
# A.Q3_11 12   390 3.071795 1.1847247 3      3.089744 1.4826 1   5   4
# A.Q3_12 13   390 2.920513 1.1252374 3      2.926282 1.4826 1   5   4
# A.Q3_13 14   390 2.733333 1.1871924 3      2.682692 1.4826 1   5   4
# A.Q3_29 15   390 3.758974 1.0432099 4      3.858974 1.4826 1   5   4
# A.Q3_14 16   390 3.507692 1.1125331 4      3.567308 1.4826 1   5   4
# A.Q3_15 17   390 3.776923 1.0135234 4      3.875000 1.4826 1   5   4
# A.Q3_16 18   390 3.300000 1.0967350 3      3.326923 1.4826 1   5   4
# A.Q3_17 19   390 2.948718 1.1683204 3      2.935897 1.4826 1   5   4
# A.Q3_18 20   390 3.633333 1.0096790 4      3.701923 1.4826 1   5   4
# A.Q3_19 21   390 3.438462 1.1562094 4      3.487179 1.4826 1   5   4
# A.Q3_20 22   390 4.238462 0.8764603 4      4.358974 1.4826 1   5   4
# A.Q3_21 23   390 2.700000 1.1715347 3      2.634615 1.4826 1   5   4
# A.Q3_22 24   390 3.738462 1.1146640 4      3.839744 1.4826 1   5   4
# A.Q3_23 25   390 3.602564 1.0961459 4      3.669872 1.4826 1   5   4
# A.Q3_24 26   390 3.274359 1.1196350 3      3.291667 1.4826 1   5   4
# A.Q3_25 27   390 3.628205 1.2817583 4      3.769231 1.4826 1   5   4
# A.Q3_30 28   390 3.920513 0.9968277 4      4.038462 1.4826 1   5   4
# A.Q3_31 29   390 3.535897 1.0886154 4      3.599359 1.4826 1   5   4
# A.Q3_26 30   390 3.646154 1.0935300 4      3.730769 1.4826 1   5   4
# A.Q3_27 31   390 3.482051 1.1970125 4      3.551282 1.4826 1   5   4
#         skew        kurtosis    se
# A.Q3_1  -0.10158507 -0.87708282 0.06140718
# A.Q3_2  -0.73907202  0.01005910 0.04799189
# A.Q3_3  -0.11600546 -1.13292162 0.06743302
# A.Q3_4  -0.02529059 -0.87576847 0.06017652
# A.Q3_5   0.28703694 -1.04288136 0.06257409
# A.Q3_6  -0.68328788 -0.20776357 0.05496621
# A.Q3_7  -0.45748263 -0.63956003 0.05829119
# A.Q3_8  -0.56402042 -0.55744035 0.05899556
# A.Q3_9  -0.80028413 -0.08352287 0.05307396
# A.Q3_28 -0.60514176 -0.25180729 0.05303764
# A.Q3_10 -0.09113811 -0.88960800 0.05885387
# A.Q3_11 -0.15688587 -0.86501539 0.05999087
# A.Q3_12  0.01556163 -0.79431951 0.05697861
# A.Q3_13  0.29423435 -0.85613681 0.06011583
# A.Q3_29 -0.57914574 -0.26804702 0.05282499
# A.Q3_14 -0.33212145 -0.62048092 0.05633530
# A.Q3_15 -0.54982916 -0.25045530 0.05132175
# A.Q3_16 -0.30834927 -0.65078738 0.05553534
# A.Q3_17  0.07997673 -0.77902738 0.05916021
# A.Q3_18 -0.40243471 -0.29321910 0.05112708
# A.Q3_19 -0.29844805 -0.83594531 0.05854694
# A.Q3_20 -1.14274484  1.22349320 0.04438129
# A.Q3_21  0.34770112 -0.66533153 0.05932297
# A.Q3_22 -0.57356843 -0.53228665 0.05644320
# A.Q3_23 -0.41902887 -0.63758035 0.05550551
# A.Q3_24 -0.13595950 -0.74141418 0.05669492
# A.Q3_25 -0.62845242 -0.70874036 0.06490435
# A.Q3_30 -0.78858405  0.18243219 0.05047633
# A.Q3_31 -0.41373045 -0.50111702 0.05512418
# A.Q3_26 -0.48026275 -0.47568747 0.05537304
# A.Q3_27 -0.33448280 -0.86527329 0.06061309

# %%
describe(MyData[vec_CQ1])
# Out:
#        vars n   mean     sd        median trimmed  mad    min max range
# C.Q1_1 1    390 3.525641 0.8829193 4      3.564103 1.4826 1   5   4
# C.Q1_2 2    390 3.646154 1.1098637 4      3.737179 1.4826 1   5   4
# C.Q1_3 3    390 3.828205 1.0773310 4      3.971154 1.4826 1   5   4
# C.Q1_4 4    390 4.400000 0.8294081 5      4.560897 0.0000 1   5   4
# C.Q1_5 5    390 4.433333 0.7584429 5      4.570513 0.0000 1   5   4
# C.Q1_6 6    390 4.282051 0.8438106 4      4.410256 1.4826 1   5   4
# C.Q1_7 7    390 2.556410 1.1719285 2      2.474359 1.4826 1   5   4
#        skew       kurtosis   se
# C.Q1_1 -0.5805395  0.3508899 0.04470836
# C.Q1_2 -0.5215218 -0.4510728 0.05620013
# C.Q1_3 -0.9357689  0.3750404 0.05455277
# C.Q1_4 -1.5822386  2.6699605 0.04199871
# C.Q1_5 -1.6081708  3.5202279 0.03840525
# C.Q1_6 -1.2338694  1.5899220 0.04272801
# C.Q1_7  0.4428976 -0.5987936 0.05934291

# %% [markdown]
# ### Explorative Faktorenanalyse

# %%
items.parallel <- fa.parallel(convert_data(MyData,c(vec_AQ3)), fa="both")
# Out:
# Parallel analysis suggests that the number of factors =  7  and the number of components =  5
# Plot with title "Parallel Analysis Scree Plots"

# %% [markdown]
# Versuchsweise wurden auch Tests mit Itemgruppen AQ2 und CQ1 sowie von Kombinationen der drei Itemgruppen durchgeführt. Diese Tests zeigen, dass die Anwendung einer Faktorenanalyse in diesen Fällen zu keinen sinnvollen Ergebnissen führt. Wir können daraus schließen, dass es sinnvoll ist, diese Teile in der Erhebung zu trennen und auch getrennt zu analysieren.

# %% [markdown]
# ### Faktorenanalyse

# %%
FA_AQ3 <- fa(convert_data(MyData,vec_AQ3), nfactors = 6, rotate = "varimax")
diagram(FA_AQ3)
# Out:
# Plot with title "Factor Analysis"

# %% [markdown]
# ### Hypothese zum Ergebnis der explorativen Faktorenanalyse:
#
# * MR1: Kontextwissen (Textsorte, behandeltes Thema, kulturelles Wissen...)
# * MR2: intralinguale Hinweise (Wortbildung, morphosyntaktische Regularitäten, Orthographie) + Konnektoren, Erklärungshilfen
# * MR3: interlinguale Hinweise (inkl. Ethymologie)
# * MR4: engerer Kontext, Analyse auf Satzebene (Syntax, semantische Relationen)
# * MR5: metakognitive Strategien
# * MR6: Bilder, Grafiken, Symbole, Zahlen, Kommunikationssituation

# %%
FA_AQ3
# Out:
# Factor Analysis using method =  minres
# Call: fa(r = convert_data(MyData, vec_AQ3), nfactors = 6, rotate = "varimax")
# Standardized loadings (pattern matrix) based upon correlation matrix
#           MR2   MR4   MR1   MR5   MR6   MR3    h2   u2 com
# A.Q3_1  -0.02  0.08  0.07 -0.02 -0.03  0.50 0.265 0.73 1.1
# A.Q3_2   0.10 -0.18  0.09  0.12  0.03  0.64 0.474 0.53 1.3
# A.Q3_3  -0.03 -0.01  0.11  0.07  0.06  0.49 0.260 0.74 1.2
# A.Q3_4  -0.01  0.10 -0.04  0.12  0.15  0.48 0.281 0.72 1.5
# A.Q3_5   0.20  0.30  0.08  0.08  0.03  0.41 0.313 0.69 2.6
# A.Q3_6   0.80  0.13  0.09  0.05 -0.05  0.08 0.679 0.32 1.1
# A.Q3_7   0.79  0.19  0.12  0.12 -0.02  0.04 0.696 0.30 1.2
# A.Q3_8   0.80  0.17  0.12  0.10  0.02 -0.03 0.700 0.30 1.2
# A.Q3_9   0.54  0.16  0.06  0.16  0.10  0.05 0.362 0.64 1.5
# A.Q3_28  0.22  0.18  0.16  0.40  0.07  0.12 0.283 0.72 2.7
# A.Q3_10  0.40  0.49  0.03  0.17  0.09 -0.03 0.439 0.56 2.3
# A.Q3_11  0.24  0.72  0.07  0.16  0.07  0.02 0.611 0.39 1.4
# A.Q3_12  0.22  0.62  0.14  0.18  0.02  0.05 0.485 0.52 1.5
# A.Q3_13  0.13  0.58  0.18  0.00  0.09  0.05 0.394 0.61 1.4
# A.Q3_29  0.18  0.24  0.20  0.47  0.11 -0.02 0.369 0.63 2.5
# A.Q3_14  0.36  0.30  0.18  0.32  0.19 -0.08 0.394 0.61 4.2
# A.Q3_15  0.32  0.16  0.32  0.29  0.16  0.00 0.338 0.66 3.9
# A.Q3_16  0.16  0.33  0.40  0.29  0.16 -0.06 0.402 0.60 3.6
# A.Q3_17  0.05  0.32  0.54  0.10  0.16  0.10 0.451 0.55 2.0
# A.Q3_18  0.12  0.09  0.81  0.20  0.17  0.09 0.746 0.25 1.3
# A.Q3_19  0.15  0.10  0.58  0.15  0.20  0.15 0.455 0.55 1.8
# A.Q3_20  0.26  0.02  0.41  0.29  0.19  0.17 0.389 0.61 3.6
# A.Q3_21  0.03  0.35  0.24  0.01  0.43  0.07 0.375 0.63 2.6
# A.Q3_22  0.03  0.03  0.16  0.10  0.68  0.08 0.504 0.50 1.2
# A.Q3_23  0.05  0.13  0.17  0.12  0.80  0.06 0.710 0.29 1.2
# A.Q3_24  0.04  0.21  0.39  0.15  0.48  0.13 0.474 0.53 2.8
# A.Q3_25  0.02  0.20  0.05  0.12  0.11  0.05 0.074 0.93 2.6
# A.Q3_30  0.22 -0.11  0.10  0.35  0.18  0.08 0.231 0.77 2.9
# A.Q3_31 -0.01  0.13  0.02  0.66  0.04  0.06 0.462 0.54 1.1
# A.Q3_26  0.12  0.08  0.16  0.65  0.01  0.19 0.504 0.50 1.4
# A.Q3_27  0.08  0.16  0.25  0.35  0.08  0.12 0.239 0.76 2.8
#
#                        MR2  MR4  MR1  MR5  MR6  MR3
# SS loadings           3.06 2.45 2.30 2.15 1.88 1.51
# Proportion Var        0.10 0.08 0.07 0.07 0.06 0.05
# Cumulative Var        0.10 0.18 0.25 0.32 0.38 0.43
# Proportion Explained  0.23 0.18 0.17 0.16 0.14 0.11
# Cumulative Proportion 0.23 0.41 0.59 0.75 0.89 1.00
#
# Mean item complexity =  2
# Test of the hypothesis that 6 factors are sufficient.
#
# The degrees of freedom for the null model are  465  and the objective function was  11.05 with Chi Square of  4174.33
# The degrees of freedom for the model are 294  and the objective function was  1.36
#
# The root mean square of the residuals (RMSR) is  0.03
# The df corrected root mean square of the residuals is  0.04
#
# The harmonic number of observations is  390 with the empirical chi square  346.15  with prob <  0.02
# The total number of observations was  390  with Likelihood Chi Square =  508.53  with prob <  1.1e-13
#
# Tucker Lewis Index of factoring reliability =  0.907
# RMSEA index =  0.045  and the 90 % confidence intervals are  0.037 0.05
# BIC =  -1245.52
# Fit based upon off diagonal values = 0.98
# Measures of factor score adequacy
#                                                    MR2  MR4  MR1  MR5  MR6  MR3
# Correlation of (regression) scores with factors   0.92 0.87 0.87 0.84 0.87 0.82
# Multiple R square of scores with factors          0.85 0.75 0.76 0.70 0.77 0.67
# Minimum correlation of possible factor scores     0.70 0.50 0.53 0.40 0.53 0.35

# %% [markdown]
# Export FA_weights:

# %%
#write.csv2(FA_AQ3$weights, file ="D:\\Daten\\DISS\\Daten\\FA_weights.csv",row.names=TRUE)
# Out:
# Error in write.table(FA_AQ3$weights, file = "D:\\Daten\\DISS\\Daten\\FA_weights.csv", : unbenutztes Argument (encoding = "utf-16")
# Traceback:
#
# 1. write.csv2(FA_AQ3$weights, file = "D:\\Daten\\DISS\\Daten\\FA_weights.csv",
#  .     row.names = TRUE, , encoding = "utf-16")
# 2. eval.parent(Call)
# 3. eval(expr, p)
# 4. eval(expr, p)

# %% [markdown]
# GRM notwendig? - ausführen oder löschen!

# %% [markdown]
# ### GRM

# %%
library("ltm")

# %%
matrix_AQ3 <- convert_data(MyData,vec_AQ3)

# %%
get_fitems <- function(F,f,thr){
    names(F$loadings[F$loadings[,f] > thr, f])
}

# %%
get_datagrm <- function(df,F,f,thr,type='factor'){
    if (type == 'factor'){
        DF <- data.frame(apply(df[get_fitems(F,f,thr)],2,as.factor))
    }else {
        DF <- data.frame(apply(df[get_fitems(F,f,thr)],2,as.numeric))
    }
    DF
}

# %% [markdown]
# #### GRM-Funktion

# %%
grm_full <- function (df,F,f,thr){
    results <- list()
    results$rcor <- rcor.test(get_datagrm(df,F,f,thr), method = "kendall")
    results$fit1 <- grm(get_datagrm(df,F,f,thr), constrained = TRUE)
    results$fit2 <- grm(get_datagrm(df,F,f,thr), constrained = FALSE)
    results$anova <- anova(results$fit1,results$fit2)
    results$margins1 <- margins(results$fit1)
    results$margins2 <- margins(results$fit2)
    results$info1 <- information(results$fit1, c(-4, 4))
    results$info2 <- information(results$fit2, c(-4, 4))
    results$alpha <- alpha(get_datagrm(df,F,f,thr,type='num'))
    results
}

# %% [markdown]
# #### Cronbachs Alpha und Inter-Item-Korrelation für AQ3

# %%
GRM_AQ3 <- data.frame(apply(MyData[,vec_AQ3],2,as.factor))

# %%
alpha(data.frame(apply(MyData[,vec_AQ3],2,as.numeric)),check.keys = TRUE)
# Out:
# Reliability analysis
# Call: alpha(x = data.frame(apply(MyData[, vec_AQ3], 2, as.numeric)),
#     check.keys = TRUE)
#
#   raw_alpha std.alpha G6(smc) average_r S/N    ase mean   sd
#       0.88      0.89    0.92       0.2 7.8 0.0091  3.4 0.53
#
#  lower alpha upper     95% confidence boundaries
# 0.87 0.88 0.9
#
#  Reliability if an item is dropped:
#         raw_alpha std.alpha G6(smc) average_r S/N alpha se
# A.Q3_1       0.89      0.89    0.92      0.21 8.0   0.0088
# A.Q3_2       0.88      0.89    0.92      0.21 7.9   0.0090
# A.Q3_3       0.89      0.89    0.92      0.21 7.8   0.0090
# A.Q3_4       0.88      0.89    0.92      0.21 7.9   0.0090
# A.Q3_5       0.88      0.88    0.92      0.20 7.6   0.0093
# A.Q3_6       0.88      0.88    0.91      0.20 7.5   0.0094
# A.Q3_7       0.88      0.88    0.91      0.20 7.4   0.0095
# A.Q3_8       0.88      0.88    0.91      0.20 7.4   0.0095
# A.Q3_9       0.88      0.88    0.91      0.20 7.5   0.0094
# A.Q3_28      0.88      0.88    0.91      0.20 7.5   0.0094
# A.Q3_10      0.88      0.88    0.91      0.20 7.4   0.0095
# A.Q3_11      0.88      0.88    0.91      0.20 7.4   0.0096
# A.Q3_12      0.88      0.88    0.91      0.20 7.4   0.0096
# A.Q3_13      0.88      0.88    0.91      0.20 7.5   0.0094
# A.Q3_29      0.88      0.88    0.91      0.20 7.4   0.0095
# A.Q3_14      0.88      0.88    0.91      0.20 7.3   0.0096
# A.Q3_15      0.88      0.88    0.91      0.20 7.3   0.0096
# A.Q3_16      0.88      0.88    0.91      0.20 7.4   0.0096
# A.Q3_17      0.88      0.88    0.91      0.20 7.4   0.0095
# A.Q3_18      0.88      0.88    0.91      0.20 7.3   0.0096
# A.Q3_19      0.88      0.88    0.91      0.20 7.4   0.0095
# A.Q3_20      0.88      0.88    0.91      0.20 7.4   0.0095
# A.Q3_21      0.88      0.88    0.91      0.20 7.6   0.0093
# A.Q3_22      0.88      0.88    0.91      0.20 7.6   0.0093
# A.Q3_23      0.88      0.88    0.91      0.20 7.5   0.0094
# A.Q3_24      0.88      0.88    0.91      0.20 7.4   0.0095
# A.Q3_25      0.89      0.89    0.92      0.21 7.9   0.0090
# A.Q3_30      0.88      0.88    0.92      0.20 7.7   0.0092
# A.Q3_31      0.88      0.88    0.91      0.20 7.6   0.0093
# A.Q3_26      0.88      0.88    0.91      0.20 7.5   0.0094
# A.Q3_27      0.88      0.88    0.91      0.20 7.6   0.0093
#
#  Item statistics
#           n raw.r std.r r.cor r.drop mean   sd
# A.Q3_1  332  0.17  0.17  0.12   0.10  3.1 1.22
# A.Q3_2  332  0.23  0.24  0.20   0.17  4.0 0.94
# A.Q3_3  332  0.29  0.28  0.24   0.21  3.0 1.30
# A.Q3_4  332  0.28  0.28  0.24   0.22  2.9 1.17
# A.Q3_5  332  0.46  0.45  0.42   0.40  2.5 1.22
# A.Q3_6  332  0.51  0.52  0.51   0.46  3.7 1.10
# A.Q3_7  332  0.55  0.55  0.55   0.50  3.5 1.15
# A.Q3_8  332  0.55  0.54  0.54   0.49  3.6 1.17
# A.Q3_9  332  0.50  0.49  0.47   0.44  3.9 1.07
# A.Q3_28 331  0.48  0.49  0.46   0.43  3.7 1.06
# A.Q3_10 331  0.54  0.53  0.51   0.48  3.1 1.16
# A.Q3_11 331  0.60  0.59  0.58   0.55  3.0 1.19
# A.Q3_12 331  0.57  0.57  0.56   0.52  2.9 1.12
# A.Q3_13 331  0.49  0.48  0.46   0.43  2.7 1.20
# A.Q3_29 331  0.56  0.57  0.56   0.52  3.7 1.04
# A.Q3_14 331  0.60  0.60  0.58   0.55  3.5 1.15
# A.Q3_15 331  0.59  0.59  0.58   0.54  3.8 1.02
# A.Q3_16 331  0.59  0.59  0.58   0.54  3.2 1.11
# A.Q3_17 331  0.56  0.55  0.54   0.50  2.9 1.16
# A.Q3_18 331  0.60  0.61  0.61   0.56  3.6 0.99
# A.Q3_19 331  0.54  0.55  0.53   0.49  3.4 1.15
# A.Q3_20 331  0.54  0.55  0.54   0.50  4.2 0.89
# A.Q3_21 330  0.46  0.45  0.42   0.40  2.7 1.19
# A.Q3_22 330  0.42  0.43  0.41   0.36  3.8 1.08
# A.Q3_23 330  0.51  0.52  0.51   0.46  3.6 1.08
# A.Q3_24 330  0.57  0.57  0.55   0.52  3.3 1.12
# A.Q3_25 330  0.29  0.27  0.22   0.21  3.6 1.28
# A.Q3_30 330  0.37  0.38  0.34   0.31  3.9 0.99
# A.Q3_31 330  0.41  0.41  0.39   0.35  3.5 1.09
# A.Q3_26 330  0.49  0.49  0.47   0.43  3.6 1.09
# A.Q3_27 330  0.46  0.46  0.43   0.40  3.4 1.19
#
# Non missing response frequency for each item
#            1    2    3    4    5 miss
# A.Q3_1  0.14 0.18 0.31 0.24 0.13 0.00
# A.Q3_2  0.01 0.07 0.19 0.40 0.33 0.00
# A.Q3_3  0.19 0.14 0.28 0.26 0.13 0.00
# A.Q3_4  0.16 0.21 0.32 0.23 0.08 0.00
# A.Q3_5  0.27 0.27 0.21 0.20 0.05 0.00
# A.Q3_6  0.05 0.11 0.21 0.38 0.26 0.00
# A.Q3_7  0.06 0.15 0.26 0.32 0.21 0.00
# A.Q3_8  0.06 0.14 0.24 0.32 0.24 0.00
# A.Q3_9  0.03 0.08 0.22 0.32 0.35 0.00
# A.Q3_28 0.03 0.08 0.27 0.34 0.28 0.01
# A.Q3_10 0.08 0.25 0.27 0.27 0.13 0.01
# A.Q3_11 0.12 0.21 0.29 0.26 0.11 0.01
# A.Q3_12 0.11 0.27 0.31 0.24 0.08 0.01
# A.Q3_13 0.16 0.32 0.23 0.20 0.08 0.01
# A.Q3_29 0.03 0.10 0.27 0.34 0.27 0.01
# A.Q3_14 0.05 0.15 0.30 0.27 0.23 0.01
# A.Q3_15 0.02 0.09 0.27 0.34 0.28 0.01
# A.Q3_16 0.07 0.21 0.27 0.33 0.12 0.01
# A.Q3_17 0.12 0.24 0.34 0.19 0.11 0.01
# A.Q3_18 0.03 0.08 0.34 0.34 0.21 0.01
# A.Q3_19 0.05 0.18 0.26 0.31 0.20 0.01
# A.Q3_20 0.02 0.02 0.15 0.36 0.45 0.01
# A.Q3_21 0.17 0.29 0.29 0.16 0.09 0.01
# A.Q3_22 0.03 0.11 0.22 0.33 0.31 0.01
# A.Q3_23 0.03 0.14 0.26 0.34 0.23 0.01
# A.Q3_24 0.06 0.20 0.32 0.27 0.15 0.01
# A.Q3_25 0.08 0.12 0.19 0.28 0.32 0.01
# A.Q3_30 0.02 0.07 0.20 0.40 0.32 0.01
# A.Q3_31 0.05 0.13 0.28 0.33 0.21 0.01
# A.Q3_26 0.04 0.12 0.28 0.33 0.23 0.01
# A.Q3_27 0.06 0.17 0.26 0.28 0.23 0.01

# %% [markdown]
# #### GRM MR1

# %%
GRM_AQ3_MR1 <- grm_full(MyData,FA_AQ3,'MR1',0.3)

# %% [markdown]
# Für die Itemanalyse werden hier alle Items, die mit einem Wert von mindestens 0,3 auf den Faktor laden, berücksichtigt. Item A_Q_24 wird allerdings einem anderen Faktor zugerechnet.

# %%
GRM_AQ3_MR1$alpha
# Out:
# Reliability analysis
# Call: alpha(x = get_datagrm(df, F, f, thr, type = "num"))
#
#   raw_alpha std.alpha G6(smc) average_r S/N   ase mean   sd
#        0.8       0.8    0.78       0.4   4 0.017  3.4 0.76
#
#  lower alpha upper     95% confidence boundaries
# 0.76 0.8 0.83
#
#  Reliability if an item is dropped:
#         raw_alpha std.alpha G6(smc) average_r S/N alpha se
# A.Q3_16      0.77      0.78    0.75      0.41 3.5    0.019
# A.Q3_17      0.77      0.77    0.74      0.40 3.3    0.020
# A.Q3_18      0.74      0.73    0.70      0.36 2.8    0.023
# A.Q3_19      0.76      0.76    0.74      0.39 3.2    0.020
# A.Q3_20      0.79      0.79    0.76      0.43 3.8    0.019
# A.Q3_24      0.77      0.77    0.75      0.41 3.4    0.020
#
#  Item statistics
#           n raw.r std.r r.cor r.drop mean   sd
# A.Q3_16 331  0.69  0.68  0.57   0.52  3.2 1.11
# A.Q3_17 331  0.72  0.71  0.64   0.56  2.9 1.16
# A.Q3_18 331  0.80  0.81  0.78   0.70  3.6 0.99
# A.Q3_19 331  0.73  0.73  0.65   0.57  3.4 1.15
# A.Q3_20 331  0.60  0.63  0.52   0.46  4.2 0.89
# A.Q3_24 330  0.70  0.69  0.59   0.53  3.3 1.12
#
# Non missing response frequency for each item
#            1    2    3    4    5 miss
# A.Q3_16 0.07 0.21 0.27 0.33 0.12 0.01
# A.Q3_17 0.12 0.24 0.34 0.19 0.11 0.01
# A.Q3_18 0.03 0.08 0.34 0.34 0.21 0.01
# A.Q3_19 0.05 0.18 0.26 0.31 0.20 0.01
# A.Q3_20 0.02 0.02 0.15 0.36 0.45 0.01
# A.Q3_24 0.06 0.20 0.32 0.27 0.15 0.01

# %%
GRM_AQ3_MR1$rcor
# Out:
#         A.Q3_16 A.Q3_17 A.Q3_18 A.Q3_19 A.Q3_20 A.Q3_24
# A.Q3_16  *****      NA      NA      NA      NA      NA
# A.Q3_17 <0.001   *****      NA      NA      NA      NA
# A.Q3_18 <0.001  <0.001   *****      NA      NA      NA
# A.Q3_19 <0.001  <0.001  <0.001   *****      NA      NA
# A.Q3_20 <0.001  <0.001  <0.001  <0.001   *****      NA
# A.Q3_24 <0.001  <0.001  <0.001  <0.001  <0.001   *****
#
# upper diagonal part contains correlation coefficient estimates
# lower diagonal part contains corresponding p-values

# %%
GRM_AQ3_MR1$anova
# Out:
#  Likelihood Ratio Table
#                  AIC     BIC  log.Lik   LRT df p.value
# results$fit1 5186.22 5281.42 -2568.11
# results$fit2 5159.45 5273.69 -2549.72 36.77  5  <0.001

# %% [markdown]
# Vergleich von Modell 1 und 2 (fit1, fit2): mit "constrained" true/false (constrained = assumes equal discrimination parameters across items)
#
# Modell 2 passt besser (p.value unter 0.05), daher wird im Weiteren damit gearbeitet
#
# (Wenn p.value über 0.05 liegt, sollten beide Modelle getestet werden.)

# %% [markdown]
# #### Grafiken zur Visualisierung

# %%
par(mfrow = c(3, 2))
plot(GRM_AQ3_MR1$fit2, lwd = 1, cex = 0.7, legend = TRUE, cx = "left",xlab = "Latent Trait", cex.main = 0.8, cex.lab = 0.7, cex.axis = 1)
# Out:
# Plot with title "Item Response Category Characteristic Curves
# Item: A.Q3_24"

# %%
plot(GRM_AQ3_MR1$fit2, category = 1, lwd = 2, cex = 1, legend = TRUE, cx = -0.5,
     cy = 0.85, xlab = "Latent Trait", cex.main = 1, cex.lab = 1,
     cex.axis = 1)
# Out:
# Plot with title "Item Response Category Characteristic Curves - Category: 1"

# %%
GRM_AQ3_MR1$info2
# Out:
# Call:
# grm(data = get_datagrm(df, F, f, thr), constrained = FALSE)
#
# Total Information = 31.44
# Information in (-4, 4) = 30.24 (96.19%)
# Based on all the items

# %%
information(GRM_AQ3_MR1$fit2, c(-4, 4), items = c(2:4))
# Out:
# Call:
# grm(data = get_datagrm(df, F, f, thr), constrained = FALSE)
#
# Total Information = 20.92
# Information in (-4, 4) = 20.76 (99.24%)
# Based on items 2, 3, 4

# %%
20.92/31.44
# Out:
# [1] 0.6653944

# %%
information(GRM_AQ3_MR1$fit2, c(-4, 4), items = c(5))
# Out:
# Call:
# grm(data = get_datagrm(df, F, f, thr), constrained = FALSE)
#
# Total Information = 3.26
# Information in (-4, 4) = 2.66 (81.57%)
# Based on items 5

# %%
3.26/31.44
# Out:
# [1] 0.1036896

# %% [markdown]
# Items A_Q3_16 und A_Q3_20 tragen weniger zum Informationsgehalt des Faktors bei. (A_Q3_20 wurde von sehr vielen TN gewählt.)

# %% [markdown]
# #### GRM MR2

# %%
GRM_AQ3_MR2 <- grm_full(MyData,FA_AQ3,'MR2',0.3)

# %%
GRM_AQ3_MR2$alpha
# Out:
# Reliability analysis
# Call: alpha(x = get_datagrm(df, F, f, thr, type = "num"))
#
#   raw_alpha std.alpha G6(smc) average_r S/N   ase mean   sd
#       0.85      0.85    0.85      0.44 5.5 0.013  3.6 0.81
#
#  lower alpha upper     95% confidence boundaries
# 0.82 0.85 0.87
#
#  Reliability if an item is dropped:
#         raw_alpha std.alpha G6(smc) average_r S/N alpha se
# A.Q3_6       0.81      0.81    0.80      0.42 4.3    0.016
# A.Q3_7       0.81      0.81    0.79      0.41 4.2    0.016
# A.Q3_8       0.80      0.80    0.80      0.41 4.1    0.017
# A.Q3_9       0.83      0.83    0.83      0.45 4.9    0.014
# A.Q3_10      0.84      0.83    0.83      0.46 5.1    0.014
# A.Q3_14      0.84      0.84    0.83      0.46 5.1    0.014
# A.Q3_15      0.84      0.84    0.84      0.47 5.3    0.013
#
#  Item statistics
#           n raw.r std.r r.cor r.drop mean  sd
# A.Q3_6  332  0.78  0.78  0.76   0.68  3.7 1.1
# A.Q3_7  332  0.81  0.80  0.80   0.72  3.5 1.2
# A.Q3_8  332  0.82  0.82  0.81   0.73  3.6 1.2
# A.Q3_9  332  0.69  0.69  0.61   0.56  3.9 1.1
# A.Q3_10 331  0.67  0.67  0.57   0.53  3.1 1.2
# A.Q3_14 331  0.66  0.66  0.56   0.52  3.5 1.1
# A.Q3_15 331  0.62  0.63  0.53   0.49  3.8 1.0
#
# Non missing response frequency for each item
#            1    2    3    4    5 miss
# A.Q3_6  0.05 0.11 0.21 0.38 0.26 0.00
# A.Q3_7  0.06 0.15 0.26 0.32 0.21 0.00
# A.Q3_8  0.06 0.14 0.24 0.32 0.24 0.00
# A.Q3_9  0.03 0.08 0.22 0.32 0.35 0.00
# A.Q3_10 0.08 0.25 0.27 0.27 0.13 0.01
# A.Q3_14 0.05 0.15 0.30 0.27 0.23 0.01
# A.Q3_15 0.02 0.09 0.27 0.34 0.28 0.01

# %%
GRM_AQ3_MR2$anova
# Out:
#  Likelihood Ratio Table
#                  AIC     BIC  log.Lik   LRT df p.value
# results$fit1 6020.12 6130.56 -2981.06
# results$fit2 5915.53 6048.81 -2922.76 116.6  6  <0.001

# %%
plot(GRM_AQ3_MR2$fit2, category = 1, lwd = 2, cex = 1, legend = TRUE, cx = -0.5,
     cy = 0.85, xlab = "Latent Trait", cex.main = 1, cex.lab = 1,
     cex.axis = 1)
# Out:
# Plot with title "Item Response Category Characteristic Curves - Category: 1"

# %%
GRM_AQ3_MR2$info2
# Out:
# Call:
# grm(data = get_datagrm(df, F, f, thr), constrained = FALSE)
#
# Total Information = 44.38
# Information in (-4, 4) = 42.97 (96.83%)
# Based on all the items

# %%
information(GRM_AQ3_MR2$fit2, c(-4, 4), items = c(2:3))
# Out:
# Call:
# grm(data = get_datagrm(df, F, f, thr), constrained = FALSE)
#
# Total Information = 22.22
# Information in (-4, 4) = 22.22 (99.99%)
# Based on items 2, 3

# %%
5.66/44.38
# Out:
# [1] 0.1275349

# %% [markdown]
# Items A_Q3_14 und A_Q3_15 tragen nur wenig zum Informationsgehalt des Faktors bei. Beide laden auch auf andere Faktoren in ähnlicher Weise, was inhaltlich zu erkären ist.

# %% [markdown]
# #### GRM MR3

# %%
GRM_AQ3_MR3 <- grm_full(MyData,FA_AQ3,'MR3',0.3)

# %%
GRM_AQ3_MR3$alpha
# Out:
# Reliability analysis
# Call: alpha(x = get_datagrm(df, F, f, thr, type = "num"))
#
#   raw_alpha std.alpha G6(smc) average_r S/N   ase mean   sd
#       0.62      0.63    0.58      0.26 1.7 0.033  3.1 0.74
#
#  lower alpha upper     95% confidence boundaries
# 0.56 0.62 0.69
#
#  Reliability if an item is dropped:
#        raw_alpha std.alpha G6(smc) average_r S/N alpha se
# A.Q3_1      0.58      0.59    0.53      0.27 1.5    0.037
# A.Q3_2      0.54      0.54    0.48      0.23 1.2    0.041
# A.Q3_3      0.56      0.57    0.50      0.25 1.3    0.039
# A.Q3_4      0.57      0.58    0.52      0.26 1.4    0.038
# A.Q3_5      0.59      0.60    0.53      0.27 1.5    0.037
#
#  Item statistics
#          n raw.r std.r r.cor r.drop mean   sd
# A.Q3_1 332  0.62  0.61  0.45   0.35  3.1 1.22
# A.Q3_2 332  0.64  0.68  0.57   0.45  4.0 0.94
# A.Q3_3 332  0.67  0.65  0.51   0.40  3.0 1.30
# A.Q3_4 332  0.63  0.63  0.47   0.37  2.9 1.17
# A.Q3_5 332  0.61  0.61  0.43   0.34  2.5 1.22
#
# Non missing response frequency for each item
#           1    2    3    4    5 miss
# A.Q3_1 0.14 0.18 0.31 0.24 0.13    0
# A.Q3_2 0.01 0.07 0.19 0.40 0.33    0
# A.Q3_3 0.19 0.14 0.28 0.26 0.13    0
# A.Q3_4 0.16 0.21 0.32 0.23 0.08    0
# A.Q3_5 0.27 0.27 0.21 0.20 0.05    0

# %%
GRM_AQ3_MR3$anova
# Out:
#  Likelihood Ratio Table
#                  AIC     BIC  log.Lik  LRT df p.value
# results$fit1 4798.90 4878.87 -2378.45
# results$fit2 4798.91 4894.12 -2374.46 7.98  4   0.092

# %%
par(mfrow = c(3, 2))
plot(GRM_AQ3_MR3$fit1, lwd = 1, cex = 0.7, legend = TRUE, cx = "left",xlab = "Latent Trait", cex.main = 0.8, cex.lab = 0.7, cex.axis = 1)
# Out:
# Plot with title "Item Response Category Characteristic Curves
# Item: A.Q3_5"

# %%
plot(GRM_AQ3_MR3$fit1, category = 1, lwd = 2, cex = 1, legend = TRUE, cx = -0.5,
     cy = 0.85, xlab = "Latent Trait", cex.main = 1, cex.lab = 1,
     cex.axis = 1)
# Out:
# Plot with title "Item Response Category Characteristic Curves - Category: 1"

# %%
GRM_AQ3_MR3$info1
# Out:
# Call:
# grm(data = get_datagrm(df, F, f, thr), constrained = TRUE)
#
# Total Information = 14.41
# Information in (-4, 4) = 12.61 (87.47%)
# Based on all the items

# %%
information(GRM_AQ3_MR3$fit1, c(-4, 4), items = 2)
# Out:
# Call:
# grm(data = get_datagrm(df, F, f, thr), constrained = TRUE)
#
# Total Information = 3.26
# Information in (-4, 4) = 2.42 (74.07%)
# Based on items 2

# %%
3.26/14.41
# Out:
# [1] 0.2262318

# %% [markdown]
# A_Q3_2 trägt 22% zum Informationsgehalt des Faktors bei. (Sehr viele TN haben diese Strategie gewählt.) Der Wert ist ausreichend, zudem kann das Item aus inhaltlichen Gründen nicht entfernt werden.

# %% [markdown]
# #### GRM MR4

# %%
GRM_AQ3_MR4 <- grm_full(MyData,FA_AQ3,'MR4',0.4)

# %%
GRM_AQ3_MR4$alpha
# Out:
# Reliability analysis
# Call: alpha(x = get_datagrm(df, F, f, thr, type = "num"))
#
#   raw_alpha std.alpha G6(smc) average_r S/N  ase mean   sd
#       0.78      0.78    0.75      0.47 3.6 0.02  2.9 0.91
#
#  lower alpha upper     95% confidence boundaries
# 0.74 0.78 0.82
#
#  Reliability if an item is dropped:
#         raw_alpha std.alpha G6(smc) average_r S/N alpha se
# A.Q3_10      0.76      0.77    0.70      0.52 3.3    0.023
# A.Q3_11      0.67      0.67    0.59      0.40 2.0    0.032
# A.Q3_12      0.70      0.70    0.63      0.43 2.3    0.029
# A.Q3_13      0.77      0.77    0.71      0.53 3.4    0.022
#
#  Item statistics
#           n raw.r std.r r.cor r.drop mean  sd
# A.Q3_10 331  0.73  0.73  0.59   0.51  3.1 1.2
# A.Q3_11 331  0.84  0.84  0.79   0.69  3.0 1.2
# A.Q3_12 331  0.81  0.81  0.74   0.65  2.9 1.1
# A.Q3_13 331  0.73  0.72  0.57   0.50  2.7 1.2
#
# Non missing response frequency for each item
#            1    2    3    4    5 miss
# A.Q3_10 0.08 0.25 0.27 0.27 0.13 0.01
# A.Q3_11 0.12 0.21 0.29 0.26 0.11 0.01
# A.Q3_12 0.11 0.27 0.31 0.24 0.08 0.01
# A.Q3_13 0.16 0.32 0.23 0.20 0.08 0.01

# %%
GRM_AQ3_MR4$anova
# Out:
#  Likelihood Ratio Table
#                  AIC     BIC  log.Lik  LRT df p.value
# results$fit1 3710.17 3774.91 -1838.09
# results$fit2 3675.78 3751.94 -1817.89 40.4  3  <0.001

# %%
plot(GRM_AQ3_MR4$fit2, category = 1, lwd = 2, cex = 1, legend = TRUE, cx = -0.5,
     cy = 0.85, xlab = "Latent Trait", cex.main = 1, cex.lab = 1,
     cex.axis = 1)
# Out:
# Plot with title "Item Response Category Characteristic Curves - Category: 1"

# %% [markdown]
# #### GRM MR5

# %%
GRM_AQ3_MR5 <- grm_full(MyData,FA_AQ3,'MR5',0.3)

# %% [markdown]
# Für die Itemanalyse werden hier alle Items, die mit einem Wert von mindestens 0,3 auf den Faktor laden, berücksichtigt. Item A_Q_15 und A_Q_20 werden allerdings einem anderen Faktor zugerechnet.

# %%
GRM_AQ3_MR5$alpha
# Out:
# Reliability analysis
# Call: alpha(x = get_datagrm(df, F, f, thr, type = "num"))
#
#   raw_alpha std.alpha G6(smc) average_r S/N   ase mean   sd
#       0.75      0.75    0.75      0.28 3.1 0.021  3.7 0.63
#
#  lower alpha upper     95% confidence boundaries
# 0.71 0.75 0.79
#
#  Reliability if an item is dropped:
#         raw_alpha std.alpha G6(smc) average_r S/N alpha se
# A.Q3_28      0.73      0.73    0.72      0.28 2.7    0.023
# A.Q3_29      0.71      0.71    0.70      0.26 2.5    0.024
# A.Q3_15      0.73      0.73    0.72      0.28 2.7    0.023
# A.Q3_20      0.73      0.73    0.71      0.27 2.6    0.023
# A.Q3_30      0.74      0.75    0.74      0.30 3.0    0.021
# A.Q3_31      0.72      0.73    0.71      0.28 2.7    0.023
# A.Q3_26      0.71      0.72    0.70      0.26 2.5    0.024
# A.Q3_27      0.74      0.74    0.74      0.29 2.9    0.021
#
#  Item statistics
#           n raw.r std.r r.cor r.drop mean   sd
# A.Q3_28 331  0.61  0.61  0.53   0.45  3.7 1.06
# A.Q3_29 331  0.68  0.68  0.62   0.54  3.7 1.04
# A.Q3_15 331  0.60  0.61  0.53   0.45  3.8 1.02
# A.Q3_20 331  0.59  0.62  0.54   0.46  4.2 0.89
# A.Q3_30 330  0.51  0.52  0.40   0.34  3.9 0.99
# A.Q3_31 330  0.62  0.61  0.54   0.46  3.5 1.09
# A.Q3_26 330  0.67  0.66  0.61   0.53  3.6 1.09
# A.Q3_27 330  0.56  0.54  0.42   0.36  3.4 1.19
#
# Non missing response frequency for each item
#            1    2    3    4    5 miss
# A.Q3_28 0.03 0.08 0.27 0.34 0.28 0.01
# A.Q3_29 0.03 0.10 0.27 0.34 0.27 0.01
# A.Q3_15 0.02 0.09 0.27 0.34 0.28 0.01
# A.Q3_20 0.02 0.02 0.15 0.36 0.45 0.01
# A.Q3_30 0.02 0.07 0.20 0.40 0.32 0.01
# A.Q3_31 0.05 0.13 0.28 0.33 0.21 0.01
# A.Q3_26 0.04 0.12 0.28 0.33 0.23 0.01
# A.Q3_27 0.06 0.17 0.26 0.28 0.23 0.01

# %%
GRM_AQ3_MR5$anova
# Out:
#  Likelihood Ratio Table
#                  AIC     BIC  log.Lik  LRT df p.value
# results$fit1 6957.88 7083.55 -3445.94
# results$fit2 6948.28 7100.60 -3434.14 23.6  7   0.001

# %%
par(mfrow = c(4, 2))
plot(GRM_AQ3_MR5$fit2, lwd = 1, cex = 0.7, legend = TRUE, cx = "left",xlab = "Latent Trait", cex.main = 0.8, cex.lab = 0.7, cex.axis = 1)
# Out:
# Plot with title "Item Response Category Characteristic Curves
# Item: A.Q3_27"

# %%
plot(GRM_AQ3_MR5$fit2, category = 1, lwd = 2, cex = 1, legend = TRUE, cx = -0.5,
     cy = 0.85, xlab = "Latent Trait", cex.main = 1, cex.lab = 1,
     cex.axis = 1)
# Out:
# Plot with title "Item Response Category Characteristic Curves - Category: 1"

# %%
GRM_AQ3_MR5$info2
# Out:
# Call:
# grm(data = get_datagrm(df, F, f, thr), constrained = FALSE)
#
# Total Information = 26.45
# Information in (-4, 4) = 23.09 (87.29%)
# Based on all the items

# %%
information(GRM_AQ3_MR5$fit2, c(-4, 4), items = 7)
# Out:
# Call:
# grm(data = get_datagrm(df, F, f, thr), constrained = FALSE)
#
# Total Information = 4.01
# Information in (-4, 4) = 3.79 (94.55%)
# Based on items 7

# %%
2.08/26.45
# Out:
# [1] 0.07863894

# %% [markdown]
# Item A_Q3_30 trägt weniger zum Informationsgehalt des Faktors bei. (Die Strategie wurde von sehr vielen TN gewählt.)

# %% [markdown]
# #### GRM MR6

# %%
GRM_AQ3_MR6 <- grm_full(MyData,FA_AQ3,'MR6',0.4)

# %%
GRM_AQ3_MR6$alpha
# Out:
# Reliability analysis
# Call: alpha(x = get_datagrm(df, F, f, thr, type = "num"))
#
#   raw_alpha std.alpha G6(smc) average_r S/N   ase mean   sd
#       0.76      0.76    0.73      0.45 3.2 0.022  3.3 0.85
#
#  lower alpha upper     95% confidence boundaries
# 0.72 0.76 0.8
#
#  Reliability if an item is dropped:
#         raw_alpha std.alpha G6(smc) average_r S/N alpha se
# A.Q3_21      0.76      0.76    0.70      0.51 3.2    0.023
# A.Q3_22      0.70      0.70    0.63      0.44 2.4    0.029
# A.Q3_23      0.64      0.64    0.54      0.37 1.8    0.034
# A.Q3_24      0.72      0.72    0.65      0.46 2.6    0.027
#
#  Item statistics
#           n raw.r std.r r.cor r.drop mean  sd
# A.Q3_21 330  0.72  0.70  0.52   0.46  2.7 1.2
# A.Q3_22 330  0.77  0.77  0.67   0.57  3.8 1.1
# A.Q3_23 330  0.83  0.84  0.79   0.68  3.6 1.1
# A.Q3_24 330  0.75  0.75  0.62   0.54  3.3 1.1
#
# Non missing response frequency for each item
#            1    2    3    4    5 miss
# A.Q3_21 0.17 0.29 0.29 0.16 0.09 0.01
# A.Q3_22 0.03 0.11 0.22 0.33 0.31 0.01
# A.Q3_23 0.03 0.14 0.26 0.34 0.23 0.01
# A.Q3_24 0.06 0.20 0.32 0.27 0.15 0.01

# %%
GRM_AQ3_MR6$anova
# Out:
#  Likelihood Ratio Table
#                  AIC     BIC  log.Lik   LRT df p.value
# results$fit1 3584.87 3649.61 -1775.44
# results$fit2 3551.54 3627.70 -1755.77 39.33  3  <0.001

# %%
plot(GRM_AQ3_MR6$fit2, category = 1, lwd = 2, cex = 1, legend = TRUE, cx = -0.5,
     cy = 0.85, xlab = "Latent Trait", cex.main = 1, cex.lab = 1,
     cex.axis = 1)
# Out:
# Plot with title "Item Response Category Characteristic Curves - Category: 1"

# %% [markdown]
# ### Konfirmatorische Faktorenanalyse

# %% [markdown]
# Verschiedene konfirmatorische Faktorenanalysen werden durchgeführt, um zu überprüfen, wie sich die Eliminierung bestimmter Items auf die Gesamtstruktur des Fragebogens auswirkt.
#
# Aufgrund der Ergebnisse der Itemanalyse:
# * A_Q3_14
# * A_Q3_15
# * A_Q3_20
# * A_Q3_30
#
# Aus inhaltlichen Überlegungen (Reduktion der Items):
# * A_Q3_25
# * A_Q3_6, A_Q3_7, A_Q3_8

# %%
get_itemsCFA <- function(vd,vf){
    ind <- match(vd,vf)
    vf[-ind]
}

# %%
items_CFA <- get_itemsCFA(c('A.Q3_7','A.Q3_8'),colnames(MyData)[vec_AQ3])

# %%
vec_AQ3cf <- match(items_CFA,colnames(MyData))

# %%
items.parallel1 <- fa.parallel(convert_data(MyData,vec_AQ3cf), fa="both")
# Out:
# Parallel analysis suggests that the number of factors =  6  and the number of components =  5
# Plot with title "Parallel Analysis Scree Plots"

# %%
FA_AQ3cf <- fa(convert_data(MyData,vec_AQ3cf), nfactors = 6, rotate = "varimax")

# %%
diagram(FA_AQ3cf)
# Out:
# Plot with title "Factor Analysis"

# %%
FA_AQ3cf
# Out:
# Factor Analysis using method =  minres
# Call: fa(r = convert_data(MyData, vec_AQ3cf), nfactors = 6, rotate = "varimax")
# Standardized loadings (pattern matrix) based upon correlation matrix
#           MR2   MR1   MR6   MR3   MR5   MR4    h2   u2 com
# A.Q3_1   0.00 -0.04  0.05 -0.04  0.02  0.48 0.236 0.76 1.0
# A.Q3_2  -0.22  0.17  0.08  0.00  0.05  0.63 0.487 0.51 1.4
# A.Q3_3   0.01  0.00  0.13  0.03  0.11  0.51 0.291 0.71 1.2
# A.Q3_4   0.10  0.01 -0.06  0.17  0.08  0.47 0.270 0.73 1.5
# A.Q3_5   0.34  0.17  0.03  0.08  0.03  0.43 0.335 0.67 2.3
# A.Q3_6   0.27  0.62  0.09 -0.07 -0.06  0.07 0.470 0.53 1.5
# A.Q3_9   0.20  0.55  0.04  0.05  0.07  0.02 0.353 0.65 1.3
# A.Q3_28  0.14  0.37  0.12  0.10  0.29  0.11 0.272 0.73 2.9
# A.Q3_10  0.52  0.40  0.02  0.02  0.13 -0.07 0.457 0.54 2.1
# A.Q3_11  0.72  0.22  0.09  0.09  0.14  0.01 0.605 0.40 1.3
# A.Q3_12  0.63  0.26  0.13  0.03  0.11  0.04 0.499 0.50 1.5
# A.Q3_13  0.62  0.11  0.13  0.13 -0.02  0.04 0.428 0.57 1.3
# A.Q3_29  0.26  0.37  0.18  0.12  0.38  0.00 0.404 0.60 3.5
# A.Q3_14  0.38  0.41  0.14  0.16  0.20 -0.03 0.401 0.60 3.0
# A.Q3_15  0.22  0.49  0.28  0.17  0.17 -0.03 0.418 0.58 2.7
# A.Q3_16  0.37  0.19  0.41  0.20  0.21 -0.06 0.432 0.57 3.5
# A.Q3_17  0.33 -0.01  0.55  0.20  0.15  0.12 0.490 0.51 2.3
# A.Q3_18  0.09  0.23  0.82  0.22  0.09  0.07 0.788 0.21 1.4
# A.Q3_19  0.10  0.24  0.52  0.22  0.10  0.13 0.408 0.59 2.2
# A.Q3_20 -0.03  0.45  0.34  0.23  0.16  0.17 0.426 0.57 3.1
# A.Q3_21  0.38 -0.04  0.17  0.46  0.03  0.05 0.388 0.61 2.3
# A.Q3_22  0.02  0.10  0.17  0.68  0.06  0.06 0.507 0.49 1.2
# A.Q3_23  0.13  0.18  0.14  0.78  0.07  0.03 0.688 0.31 1.3
# A.Q3_24  0.23  0.12  0.34  0.52  0.09  0.13 0.472 0.53 2.6
# A.Q3_25  0.20 -0.02  0.07  0.14  0.14  0.03 0.086 0.91 3.0
# A.Q3_30 -0.13  0.35  0.09  0.20  0.26  0.10 0.264 0.74 3.2
# A.Q3_31  0.12  0.06  0.02  0.09  0.74  0.07 0.576 0.42 1.1
# A.Q3_26  0.08  0.20  0.19 -0.01  0.62  0.18 0.498 0.50 1.7
# A.Q3_27  0.18  0.15  0.24  0.07  0.29  0.14 0.220 0.78 4.0
#
#                        MR2  MR1  MR6  MR3  MR5  MR4
# SS loadings           2.73 2.31 2.05 2.00 1.60 1.48
# Proportion Var        0.09 0.08 0.07 0.07 0.06 0.05
# Cumulative Var        0.09 0.17 0.24 0.31 0.37 0.42
# Proportion Explained  0.22 0.19 0.17 0.16 0.13 0.12
# Cumulative Proportion 0.22 0.41 0.58 0.75 0.88 1.00
#
# Mean item complexity =  2.1
# Test of the hypothesis that 6 factors are sufficient.
#
# The degrees of freedom for the null model are  406  and the objective function was  9.39 with Chi Square of  3019.54
# The degrees of freedom for the model are 247  and the objective function was  1.18
#
# The root mean square of the residuals (RMSR) is  0.03
# The df corrected root mean square of the residuals is  0.04
#
# The harmonic number of observations is  331 with the empirical chi square  250.7  with prob <  0.42
# The total number of observations was  333  with Likelihood Chi Square =  373.13  with prob <  3.7e-07
#
# Tucker Lewis Index of factoring reliability =  0.92
# RMSEA index =  0.042  and the 90 % confidence intervals are  0.031 0.047
# BIC =  -1061.48
# Fit based upon off diagonal values = 0.98
# Measures of factor score adequacy
#                                                    MR2  MR1  MR6  MR3  MR5  MR4
# Correlation of (regression) scores with factors   0.88 0.83 0.88 0.87 0.83 0.82
# Multiple R square of scores with factors          0.78 0.69 0.77 0.76 0.69 0.68
# Minimum correlation of possible factor scores     0.55 0.39 0.55 0.52 0.39 0.35

# %%
alpha(data.frame(apply(MyData[,vec_AQ3cf],2,as.numeric)),check.keys=TRUE )
# Out:
# Reliability analysis
# Call: alpha(x = data.frame(apply(MyData[, vec_AQ3cf], 2, as.numeric)),
#     check.keys = TRUE)
#
#   raw_alpha std.alpha G6(smc) average_r S/N    ase mean   sd
#       0.87      0.88    0.91       0.2 7.1 0.0099  3.4 0.53
#
#  lower alpha upper     95% confidence boundaries
# 0.85 0.87 0.89
#
#  Reliability if an item is dropped:
#         raw_alpha std.alpha G6(smc) average_r S/N alpha se
# A.Q3_1       0.88      0.88    0.91      0.21 7.3   0.0096
# A.Q3_2       0.87      0.88    0.91      0.21 7.2   0.0098
# A.Q3_3       0.88      0.88    0.91      0.20 7.2   0.0097
# A.Q3_4       0.87      0.88    0.91      0.20 7.1   0.0098
# A.Q3_5       0.87      0.87    0.90      0.20 6.9   0.0101
# A.Q3_6       0.87      0.87    0.90      0.20 6.9   0.0101
# A.Q3_9       0.87      0.87    0.90      0.20 6.9   0.0102
# A.Q3_28      0.87      0.87    0.90      0.20 6.8   0.0102
# A.Q3_10      0.87      0.87    0.90      0.20 6.8   0.0103
# A.Q3_11      0.87      0.87    0.90      0.19 6.7   0.0105
# A.Q3_12      0.87      0.87    0.90      0.19 6.7   0.0104
# A.Q3_13      0.87      0.87    0.90      0.20 6.9   0.0102
# A.Q3_29      0.87      0.87    0.90      0.19 6.7   0.0104
# A.Q3_14      0.87      0.87    0.90      0.19 6.7   0.0104
# A.Q3_15      0.87      0.87    0.90      0.19 6.7   0.0104
# A.Q3_16      0.87      0.87    0.90      0.19 6.7   0.0104
# A.Q3_17      0.87      0.87    0.90      0.19 6.7   0.0104
# A.Q3_18      0.87      0.87    0.90      0.19 6.6   0.0104
# A.Q3_19      0.87      0.87    0.90      0.19 6.7   0.0104
# A.Q3_20      0.87      0.87    0.90      0.19 6.7   0.0103
# A.Q3_21      0.87      0.87    0.90      0.20 6.9   0.0102
# A.Q3_22      0.87      0.87    0.90      0.20 6.9   0.0101
# A.Q3_23      0.87      0.87    0.90      0.19 6.8   0.0103
# A.Q3_24      0.87      0.87    0.90      0.19 6.7   0.0104
# A.Q3_25      0.88      0.88    0.91      0.20 7.2   0.0098
# A.Q3_30      0.87      0.88    0.90      0.20 7.0   0.0100
# A.Q3_31      0.87      0.87    0.90      0.20 6.9   0.0101
# A.Q3_26      0.87      0.87    0.90      0.20 6.8   0.0102
# A.Q3_27      0.87      0.87    0.90      0.20 6.9   0.0102
#
#  Item statistics
#           n raw.r std.r r.cor r.drop mean   sd
# A.Q3_1  332  0.19  0.19  0.14   0.12  3.1 1.22
# A.Q3_2  332  0.24  0.25  0.21   0.18  4.0 0.94
# A.Q3_3  332  0.31  0.30  0.26   0.23  3.0 1.30
# A.Q3_4  332  0.31  0.30  0.26   0.24  2.9 1.17
# A.Q3_5  332  0.47  0.45  0.42   0.40  2.5 1.22
# A.Q3_6  332  0.45  0.45  0.43   0.39  3.7 1.10
# A.Q3_9  332  0.46  0.46  0.43   0.40  3.9 1.07
# A.Q3_28 331  0.48  0.49  0.47   0.43  3.7 1.06
# A.Q3_10 331  0.51  0.50  0.49   0.45  3.1 1.16
# A.Q3_11 331  0.59  0.58  0.58   0.53  3.0 1.19
# A.Q3_12 331  0.56  0.56  0.55   0.51  2.9 1.12
# A.Q3_13 331  0.49  0.48  0.46   0.43  2.7 1.20
# A.Q3_29 331  0.57  0.58  0.57   0.52  3.7 1.04
# A.Q3_14 331  0.58  0.58  0.57   0.53  3.5 1.15
# A.Q3_15 331  0.58  0.59  0.57   0.53  3.8 1.02
# A.Q3_16 331  0.59  0.59  0.58   0.54  3.2 1.11
# A.Q3_17 331  0.57  0.57  0.55   0.52  2.9 1.16
# A.Q3_18 331  0.61  0.62  0.62   0.57  3.6 0.99
# A.Q3_19 331  0.55  0.56  0.54   0.50  3.4 1.15
# A.Q3_20 331  0.54  0.56  0.54   0.50  4.2 0.89
# A.Q3_21 330  0.47  0.46  0.44   0.41  2.7 1.19
# A.Q3_22 330  0.44  0.44  0.42   0.38  3.8 1.08
# A.Q3_23 330  0.54  0.54  0.53   0.48  3.6 1.08
# A.Q3_24 330  0.59  0.59  0.58   0.54  3.3 1.12
# A.Q3_25 330  0.30  0.28  0.23   0.22  3.6 1.28
# A.Q3_30 330  0.36  0.38  0.34   0.30  3.9 0.99
# A.Q3_31 330  0.43  0.43  0.40   0.37  3.5 1.09
# A.Q3_26 330  0.50  0.50  0.48   0.44  3.6 1.09
# A.Q3_27 330  0.47  0.47  0.43   0.41  3.4 1.19
#
# Non missing response frequency for each item
#            1    2    3    4    5 miss
# A.Q3_1  0.14 0.18 0.31 0.24 0.13 0.00
# A.Q3_2  0.01 0.07 0.19 0.40 0.33 0.00
# A.Q3_3  0.19 0.14 0.28 0.26 0.13 0.00
# A.Q3_4  0.16 0.21 0.32 0.23 0.08 0.00
# A.Q3_5  0.27 0.27 0.21 0.20 0.05 0.00
# A.Q3_6  0.05 0.11 0.21 0.38 0.26 0.00
# A.Q3_9  0.03 0.08 0.22 0.32 0.35 0.00
# A.Q3_28 0.03 0.08 0.27 0.34 0.28 0.01
# A.Q3_10 0.08 0.25 0.27 0.27 0.13 0.01
# A.Q3_11 0.12 0.21 0.29 0.26 0.11 0.01
# A.Q3_12 0.11 0.27 0.31 0.24 0.08 0.01
# A.Q3_13 0.16 0.32 0.23 0.20 0.08 0.01
# A.Q3_29 0.03 0.10 0.27 0.34 0.27 0.01
# A.Q3_14 0.05 0.15 0.30 0.27 0.23 0.01
# A.Q3_15 0.02 0.09 0.27 0.34 0.28 0.01
# A.Q3_16 0.07 0.21 0.27 0.33 0.12 0.01
# A.Q3_17 0.12 0.24 0.34 0.19 0.11 0.01
# A.Q3_18 0.03 0.08 0.34 0.34 0.21 0.01
# A.Q3_19 0.05 0.18 0.26 0.31 0.20 0.01
# A.Q3_20 0.02 0.02 0.15 0.36 0.45 0.01
# A.Q3_21 0.17 0.29 0.29 0.16 0.09 0.01
# A.Q3_22 0.03 0.11 0.22 0.33 0.31 0.01
# A.Q3_23 0.03 0.14 0.26 0.34 0.23 0.01
# A.Q3_24 0.06 0.20 0.32 0.27 0.15 0.01
# A.Q3_25 0.08 0.12 0.19 0.28 0.32 0.01
# A.Q3_30 0.02 0.07 0.20 0.40 0.32 0.01
# A.Q3_31 0.05 0.13 0.28 0.33 0.21 0.01
# A.Q3_26 0.04 0.12 0.28 0.33 0.23 0.01
# A.Q3_27 0.06 0.17 0.26 0.28 0.23 0.01

# %% [markdown]
# Die Ergebnisse (KFA und Berechnung von Cronbachs Alpha) zeigen, dass Item A_Q3_20, A_Q3_25 und A_Q3_30 entfernt werden könnten, ohne die Struktur des Fragebogens zu beeinträchtigen.
#
# Items A_Q3_6, A_Q3_7 und A_Q3_8 können nicht ohne Weiteres auf ein Item reduziert werden. Das Entfernen eines oder mehrer dieser Items beeinträchtigt die Struktur.
#
# Die Entfernung eines oder beider der Items A_Q3_14 und A_Q3_15 würde ebenfalls die Struktur beeinflussen.

# %% [markdown]
# ### GRM CQ1

# %%
GRM_CQ1 <- data.frame(apply(MyData[,vec_CQ1],2,as.factor))

# %%
alpha(data.frame(apply(MyData[,vec_CQ1],2,as.numeric)),check.keys=TRUE )
# Out:
# Warning message in alpha(data.frame(apply(MyData[, vec_CQ1], 2, as.numeric)), check.keys = TRUE):
# "Some items were negatively correlated with total scale and were automatically reversed.
#  This is indicated by a negative sign for the variable name."
# Reliability analysis
# Call: alpha(x = data.frame(apply(MyData[, vec_CQ1], 2, as.numeric)),
#     check.keys = TRUE)
#
#   raw_alpha std.alpha G6(smc) average_r S/N   ase mean   sd
#       0.57      0.62    0.63      0.19 1.6 0.036  3.9 0.51
#
#  lower alpha upper     95% confidence boundaries
# 0.5 0.57 0.65
#
#  Reliability if an item is dropped:
#         raw_alpha std.alpha G6(smc) average_r  S/N alpha se
# C.Q1_1       0.54      0.59    0.59      0.19 1.41    0.040
# C.Q1_2       0.55      0.60    0.61      0.20 1.48    0.039
# C.Q1_3       0.57      0.61    0.61      0.21 1.57    0.037
# C.Q1_4       0.50      0.54    0.55      0.16 1.17    0.044
# C.Q1_5       0.46      0.49    0.49      0.14 0.96    0.047
# C.Q1_6       0.51      0.57    0.58      0.18 1.30    0.042
# C.Q1_7-      0.62      0.65    0.65      0.23 1.83    0.033
#
#  Item statistics
#           n raw.r std.r r.cor r.drop mean   sd
# C.Q1_1  325  0.52  0.54  0.42   0.30  3.5 0.89
# C.Q1_2  325  0.53  0.51  0.35   0.26  3.6 1.10
# C.Q1_3  325  0.49  0.47  0.34   0.21  3.7 1.11
# C.Q1_4  325  0.61  0.64  0.58   0.42  4.4 0.84
# C.Q1_5  325  0.70  0.74  0.74   0.57  4.4 0.77
# C.Q1_6  325  0.56  0.58  0.47   0.37  4.3 0.83
# C.Q1_7- 325  0.42  0.37  0.17   0.10  3.4 1.17
#
# Non missing response frequency for each item
#           1    2    3    4    5 miss
# C.Q1_1 0.03 0.09 0.34 0.46 0.08 0.02
# C.Q1_2 0.05 0.10 0.26 0.34 0.25 0.02
# C.Q1_3 0.06 0.08 0.19 0.41 0.26 0.02
# C.Q1_4 0.01 0.03 0.07 0.33 0.56 0.02
# C.Q1_5 0.01 0.01 0.08 0.37 0.54 0.02
# C.Q1_6 0.01 0.02 0.11 0.38 0.48 0.02
# C.Q1_7 0.20 0.32 0.28 0.13 0.08 0.02

# %%
rcor.test(GRM_CQ1, method = "kendall")
# Out:
#        C.Q1_1 C.Q1_2 C.Q1_3 C.Q1_4 C.Q1_5 C.Q1_6 C.Q1_7
# C.Q1_1  *****     NA     NA     NA     NA     NA     NA
# C.Q1_2  0.154  *****     NA     NA     NA     NA     NA
# C.Q1_3 <0.001  0.962  *****     NA     NA     NA     NA
# C.Q1_4 <0.001  0.002  0.002  *****     NA     NA     NA
# C.Q1_5 <0.001 <0.001 <0.001 <0.001  *****     NA     NA
# C.Q1_6  0.194 <0.001  0.381 <0.001 <0.001  *****     NA
# C.Q1_7  0.051  0.091  0.323 <0.001  0.017 <0.001  *****
#
# upper diagonal part contains correlation coefficient estimates
# lower diagonal part contains corresponding p-values

# %%
fit1_C <- grm(GRM_CQ1, constrained = TRUE)
fit2_C <- grm(GRM_CQ1, constrained = FALSE)

# %%
anova(fit1_C,fit2_C)
# Out:
#  Likelihood Ratio Table
#            AIC     BIC  log.Lik    LRT df p.value
# fit1_C 5625.94 5736.38 -2783.97
# fit2_C 5480.37 5613.65 -2705.18 157.58  6  <0.001

# %%
plot(fit2_C, category = 1, lwd = 2, cex = 1, legend = TRUE, cx = -0.5,
     cy = 0.85, xlab = "Latent Trait", cex.main = 1, cex.lab = 1,
     cex.axis = 1)
# Out:
# Plot with title "Item Response Category Characteristic Curves - Category: 1"

# %% [markdown]
# ### GRM AQ2

# %%
GRM_AQ2 <- data.frame(apply(MyData[,vec_AQ2],2,as.factor))

# %%
alpha(data.frame(apply(MyData[,vec_AQ2],2,as.numeric)),check.keys=TRUE )
# Out:
# Warning message in alpha(data.frame(apply(MyData[, vec_AQ2], 2, as.numeric)), check.keys = TRUE):
# "Some items were negatively correlated with total scale and were automatically reversed.
#  This is indicated by a negative sign for the variable name."
# Reliability analysis
# Call: alpha(x = data.frame(apply(MyData[, vec_AQ2], 2, as.numeric)),
#     check.keys = TRUE)
#
#   raw_alpha std.alpha G6(smc) average_r  S/N   ase mean  sd
#        0.5       0.5    0.54      0.12 0.98 0.042    3 0.5
#
#  lower alpha upper     95% confidence boundaries
# 0.42 0.5 0.58
#
#  Reliability if an item is dropped:
#         raw_alpha std.alpha G6(smc) average_r  S/N alpha se
# A.Q2_1       0.50      0.49    0.53      0.14 0.96    0.042
# A.Q2_2       0.42      0.41    0.45      0.10 0.69    0.049
# A.Q2_3       0.45      0.45    0.46      0.12 0.81    0.046
# A.Q2_4       0.44      0.44    0.46      0.11 0.77    0.047
# A.Q2_5-      0.46      0.47    0.49      0.13 0.87    0.046
# A.Q2_6-      0.41      0.42    0.45      0.11 0.72    0.050
# A.Q2_7-      0.52      0.52    0.55      0.15 1.10    0.041
#
#  Item statistics
#           n raw.r std.r r.cor r.drop mean   sd
# A.Q2_1  333  0.45  0.44  0.23  0.155  2.5 1.09
# A.Q2_2  333  0.55  0.58  0.48  0.337  3.6 0.87
# A.Q2_3  333  0.51  0.51  0.43  0.261  3.8 0.97
# A.Q2_4  333  0.54  0.54  0.44  0.285  4.0 1.00
# A.Q2_5- 333  0.50  0.48  0.35  0.240  2.5 0.99
# A.Q2_6- 333  0.61  0.57  0.48  0.329  2.7 1.15
# A.Q2_7- 333  0.32  0.36  0.14  0.079  1.7 0.86
#
# Non missing response frequency for each item
#           1    2    3    4    5 miss
# A.Q2_1 0.19 0.30 0.34 0.12 0.05    0
# A.Q2_2 0.02 0.06 0.40 0.39 0.13    0
# A.Q2_3 0.02 0.08 0.22 0.42 0.26    0
# A.Q2_4 0.01 0.08 0.21 0.30 0.41    0
# A.Q2_5 0.03 0.13 0.34 0.35 0.15    0
# A.Q2_6 0.08 0.17 0.29 0.32 0.15    0
# A.Q2_7 0.01 0.04 0.10 0.35 0.50    0

# %%
rcor.test(GRM_AQ2, method = "kendall")
# Out:
#        A.Q2_1 A.Q2_2 A.Q2_3 A.Q2_4 A.Q2_5 A.Q2_6 A.Q2_7
# A.Q2_1  *****  0.251  0.014  0.027 -0.022 -0.053 -0.121
# A.Q2_2 <0.001  *****  0.212  0.159 -0.011 -0.098 -0.202
# A.Q2_3  0.758 <0.001  *****  0.463 -0.038 -0.136  0.104
# A.Q2_4  0.559  0.001 <0.001  ***** -0.055 -0.134  0.058
# A.Q2_5  0.628  0.812  0.410  0.238  *****  0.412  0.067
# A.Q2_6  0.243  0.035  0.003  0.004 <0.001  *****  0.086
# A.Q2_7  0.011 <0.001  0.030  0.228  0.161  0.069  *****
#
# upper diagonal part contains correlation coefficient estimates
# lower diagonal part contains corresponding p-values

# %%
fit1_AQ2 <- grm(GRM_AQ2, constrained = TRUE)
fit2_AQ2 <- grm(GRM_AQ2, constrained = FALSE)

# %%
anova(fit1_AQ2,fit2_AQ2)
# Out:
#  Likelihood Ratio Table
#              AIC     BIC  log.Lik    LRT df p.value
# fit1_AQ2 6580.00 6690.43 -3261.00
# fit2_AQ2 6150.97 6284.25 -3040.48 441.03  6  <0.001

# %%
plot(fit2_AQ2, category = 1, lwd = 2, cex = 1, legend = TRUE, cx = -0.5,
     cy = 0.85, xlab = "Latent Trait", cex.main = 1, cex.lab = 1,
     cex.axis = 1)
# Out:
# Plot with title "Item Response Category Characteristic Curves - Category: 1"
